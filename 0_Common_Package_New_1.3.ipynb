# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/TestGraphTheory/blob/main/0_Common_Package_New_1.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset1=pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/2023-10-15.csv')
dataset1
# Out:
#                             Package  Downloads  Overall  Binary-Artifacts  \
# 0                           urllib3  395719124     8.54              10.0
# 1                               tuf      61209     8.22              10.0
# 2                       flatbuffers   13067553     7.73              10.0
# 3                charset-normalizer  277662353     7.54              10.0
# 4                          requests  321150859     7.51              10.0
# ...                             ...        ...      ...               ...
# 7995                          covid      33267     0.00               NaN
# 7996             collate-sqllineage      33261     0.00               NaN
# 7997                          five9      33257     0.00               NaN
# 7998  robotframework-archivelibrary      33166     0.00               NaN
# 7999              sphinx-jsonschema      33164     0.00               NaN
#
#       Branch-Protection  CII-Best-Practices  Code-Review  Dangerous-Workflow  \
# ...

# %%
column_to_extract = 'Package'
input_csv_path = 'https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/2023-10-15.csv'

try:
    column_data = pd.read_csv(input_csv_path, usecols=[column_to_extract])[column_to_extract]
    output_csv_path = '/content/column_data1.csv'
    column_data.to_csv(output_csv_path, index=False, header=[column_to_extract])
    print(f"Column '{column_to_extract}' extracted and saved to '{output_csv_path}'.")
except KeyError:
    print(f"Column '{column_to_extract}' not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Column 'Package' extracted and saved to '/content/column_data1.csv'.

# %%
dataset11=pd.read_csv('/content/column_data1.csv')
dataset11
# Out:
#                             Package
# 0                           urllib3
# 1                               tuf
# 2                       flatbuffers
# 3                charset-normalizer
# 4                          requests
# ...                             ...
# 7995                          covid
# 7996             collate-sqllineage
# 7997                          five9
# 7998  robotframework-archivelibrary
# 7999              sphinx-jsonschema
#
# [8000 rows x 1 columns]

# %%
dataset2=pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Agg_RS_full_2.csv')
dataset2
# Out:
#        Unnamed: 0.1  Unnamed: 0     Id                Label  Degree  \
# 0                 0           0      0     gromacs-py-2.0.3       5
# 1                 1           1      1     matplotlib-3.7.1     655
# 2                 2           2      2  os-command-py-1.1.0       2
# 3                 3           3      3         pandas-2.0.0     849
# 4                 4           4      4   pdb-manip-py-1.4.2       5
# ...             ...         ...    ...                  ...     ...
# 13569         13569       13569  13569           glover-0.1       5
# 13570         13570       13570  13570         bsb-4.0.0a51      22
# 13571         13571       13571  13571       bsb-hdf5-0.7.4       3
# 13572         13572       13572  13572           errr-1.2.0       1
# 13573         13573       13573  13573        morphio-3.3.4       2
#
#        Pageranks  Eigencentrality        Package  FinalRiskScore  In_reach  \
# ...

# %%
column_to_extract = 'Package'
input_csv_path = 'https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Agg_RS_full_2.csv'

try:
    column_data = pd.read_csv(input_csv_path, usecols=[column_to_extract])[column_to_extract]
    output_csv_path = '/content/column_data2.csv'
    column_data.to_csv(output_csv_path, index=False, header=[column_to_extract])
    print(f"Column '{column_to_extract}' extracted and saved to '{output_csv_path}'.")
except KeyError:
    print(f"Column '{column_to_extract}' not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Column 'Package' extracted and saved to '/content/column_data2.csv'.

# %%
dataset22=pd.read_csv('/content/column_data2.csv')
dataset22
# Out:
#              Package
# 0         gromacs-py
# 1         matplotlib
# 2      os-command-py
# 3             pandas
# 4       pdb-manip-py
# ...              ...
# 13569         glover
# 13570         bsb- a
# 13571        bsb-hdf
# 13572           errr
# 13573        morphio
#
# [13574 rows x 1 columns]

# %%
dataset3=pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Packages-from-Data3-output.csv')
dataset3
# Out:
#            Package
# 0            green
# 1           holehe
# 2          jishaku
# 3     python-whois
# 4           vk-api
# ...            ...
# 6141    sqlalchemy
# 6142  torchmetrics
# 6143       urllib3
# 6144    virtualenv
# 6145          yapf
#
# [6146 rows x 1 columns]

# %%
input_csv_path = 'https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Packages-from-Data3-output.csv'
column_to_store = 'Package'
try:
    df = pd.read_csv(input_csv_path)
    df['Package URL'] = df['Package'].str[31:]
    output_csv_path = '/content/column_data3.csv'
    df[column_to_store].to_csv(output_csv_path, index=False, header=[column_to_store])
    print(f"Column '{column_to_store}' stored to '{output_csv_path}' after removing rows containing '{substring_to_remove}'.")
except KeyError:
    print(f"Column '{column_to_extract}' not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: name 'substring_to_remove' is not defined

# %%
dataset33=pd.read_csv('/content/column_data3.csv')
dataset33
# Out:
#            Package
# 0            green
# 1           holehe
# 2          jishaku
# 3     python-whois
# 4           vk-api
# ...            ...
# 6141    sqlalchemy
# 6142  torchmetrics
# 6143       urllib3
# 6144    virtualenv
# 6145          yapf
#
# [6146 rows x 1 columns]

# %%
file1 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/2023-10-15.csv')
file2 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Agg_RS_full_2.csv')
file3 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Packages-from-Data3-output.csv')

column_name = 'Package'
similar_values = set(file1[column_name]) & set(file2[column_name]) & set(file3[column_name])

result_df = pd.DataFrame({'SimilarValues': list(similar_values)})

output_path = '/content/finalOutput.csv'

result_df.to_csv(output_path, index=False)

print(f'Similar values in column "{column_name}" from the three CSV files saved to "{output_path}".')
# Out:
# Similar values in column "Package" from the three CSV files saved to "/content/finalOutput.csv".

# %%
output=pd.read_csv('/content/finalOutput.csv')
output
# Out:
#           SimilarValues
# 0      geventhttpclient
# 1          mbstrdecoder
# 2           marshmallow
# 3            inflection
# 4              libclang
# ...                 ...
# 1888  opentelemetry-sdk
# 1889       bravado-core
# 1890             mccabe
# 1891               zeep
# 1892          imagehash
#
# [1893 rows x 1 columns]

# %%
import pandas as pd

column_name = 'Package'

df1 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/2023-10-15.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Agg_RS_full_2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Packages-from-Data3-output.csv')

common_values = set(df1[column_name]) & set(df2[column_name]) & set(df3[column_name])

filtered_df1 = df1[df1[column_name].isin(common_values)]
filtered_df2 = df2[df2[column_name].isin(common_values)]
filtered_df3 = df3[df3[column_name].isin(common_values)]

result_df = pd.concat([filtered_df1, filtered_df2, filtered_df3], axis=1)

output_csv_path = '/content/result_end.csv'

result_df.to_csv(output_csv_path, index=False)

print(f"Rows with common values in '{column_name}' from the three CSV files saved to 'result.csv'.")
# Out:
# Rows with common values in 'Package' from the three CSV files saved to 'result.csv'.

# %%
out=pd.read_csv('/content/result_end.csv')
out
# Out:
#                  Package    Downloads  Overall  Binary-Artifacts  \
# 0            flatbuffers   13067553.0     7.73              10.0
# 1     charset-normalizer  277662353.0     7.54              10.0
# 2               requests  321150859.0     7.51              10.0
# 3                pyhanko     499865.0     6.95              10.0
# 4             defusedxml   22131021.0     6.84              10.0
# ...                  ...          ...      ...               ...
# 5695                 NaN          NaN      NaN               NaN
# 5696                 NaN          NaN      NaN               NaN
# 5697                 NaN          NaN      NaN               NaN
# 5698                 NaN          NaN      NaN               NaN
# 5699                 NaN          NaN      NaN               NaN
#
#       Branch-Protection  CII-Best-Practices  Code-Review  Dangerous-Workflow  \
# 0                   NaN                 0.0          7.0                10.0
# ...

# %%
import pandas as pd
dataset1=pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/2023-10-15.csv')
column_to_extract = 'Package'
input_csv_path = 'https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/2023-10-15.csv'

try:
    column_data = pd.read_csv(input_csv_path, usecols=[column_to_extract])[column_to_extract]
    output_csv_path = '/content/column_data1.csv'
    column_data.to_csv(output_csv_path, index=False, header=[column_to_extract])
    print(f"Column '{column_to_extract}' extracted and saved to '{output_csv_path}'.")
except KeyError:
    print(f"Column '{column_to_extract}' not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")

dataset11=pd.read_csv('/content/column_data1.csv')
dataset2=pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Agg_RS_full_2.csv')

column_to_extract = 'Package'
input_csv_path = 'https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Agg_RS_full_2.csv'

try:
    column_data = pd.read_csv(input_csv_path, usecols=[column_to_extract])[column_to_extract]
    output_csv_path = '/content/column_data2.csv'
    column_data.to_csv(output_csv_path, index=False, header=[column_to_extract])
    print(f"Column '{column_to_extract}' extracted and saved to '{output_csv_path}'.")
except KeyError:
    print(f"Column '{column_to_extract}' not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")

dataset22=pd.read_csv('/content/column_data2.csv')


dataset3=pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Snyk_Packages.csv')

column_to_store = 'Package'
input_csv_path = 'https://raw.githubusercontent.com/tanzirmehedi/Merge-Datasets/main/Snyk_Packages.csv'

try:
    df = pd.read_csv(input_csv_path)
    df['Package URL'] = df['Package'].str[31:]
    output_csv_path = '/content/column_data3.csv'
    df[column_to_store].to_csv(output_csv_path, index=False, header=[column_to_store])
    print(f"Column '{column_to_store}' stored to '{output_csv_path}' after removing rows containing '{substring_to_remove}'.")
except KeyError:
    print(f"Column '{column_to_extract}' not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")

dataset33=pd.read_csv('/content/column_data3.csv')
# Out:
# Column 'Package' extracted and saved to '/content/column_data1.csv'.
# Column 'Package' extracted and saved to '/content/column_data2.csv'.
# An error occurred: name 'substring_to_remove' is not defined

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/2023-10-15.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Agg_RS_full_2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Snyk_Packages.csv')

column_name = 'Package'
similar_values = set(df1[column_name]) & set(df2[column_name]) & set(df3[column_name])

result_df = pd.DataFrame({'SimilarValues': list(similar_values)})

output_path = '/content/finalOutput.csv'

result_df.to_csv(output_path, index=False)

print(f'Similar values in column "{column_name}" from the three CSV files saved to "{output_path}".')
# Out:
# Similar values in column "Package" from the three CSV files saved to "/content/finalOutput.csv".

# %%
import pandas as pd

column_name = 'Package'

df1 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/2023-10-15.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Agg_RS_full_2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Snyk_Packages.csv')


common_values = set(df1[column_name]) & set(df2[column_name]) & set(df3[column_name])

filtered_df1 = df1[df1[column_name].isin(common_values)]
filtered_df2 = df2[df2[column_name].isin(common_values)]
filtered_df3 = df3[df3[column_name].isin(common_values)]

result_df = pd.concat([filtered_df1, filtered_df2, filtered_df3], axis=1)

output_csv_path = '/content/result_end.csv'

result_df.to_csv(output_csv_path, index=False)

print(f"Rows with common values in '{column_name}' from the three CSV files saved to 'result.csv'.")
# Out:
# Rows with common values in 'Package' from the three CSV files saved to 'result.csv'.

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/2023-10-15.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Agg_RS_full_2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/rahmanziaur/TestGraphTheory/main/Merge-Datasets-main/Snyk_Packages.csv')


merged_df = pd.merge(df1, df2, on='Package', how='inner')
merged_df = pd.merge(merged_df, df3, on='Package', how='inner')

merged_df = merged_df[['Package', 'Overall', 'FinalRiskScore', 'Score', 'Id', 'Label', 'Degree', 'Pageranks', 'Eigencentrality', 'In_reach']].drop_duplicates('Package')

merged_df.to_csv('merged_file.csv', index=False)

print("Merged CSV file has been created")
# Out:
# Merged CSV file has been created

# %%
end_file = pd.read_csv('/content/merged_file.csv')
end_file
# Out:
#                  Package  Overall  FinalRiskScore  Score     Id  \
# 0            flatbuffers     7.73        0.638825     99    675
# 1     charset-normalizer     7.54        0.753982     91     33
# 2               requests     7.51        0.515598     96     31
# 3                pyhanko     6.95        0.657218     87  10775
# 4             defusedxml     6.84        0.934874     75    485
# ...                  ...      ...             ...    ...    ...
# 1888               dowhy     0.00        0.587851     85    259
# 1889           leidenalg     0.00        0.645948     76   4006
# 1890              geemap     0.00        0.742364     90   4999
# 1891          xds-protos     0.00        0.649163     93   2384
# 1892               mpire     0.00        0.667874     78  13350
#
#                          Label  Degree  Pageranks  Eigencentrality  In_reach
# 0           flatbuffers-23.3.3       7   0.000108         0.004440         1
# ...
